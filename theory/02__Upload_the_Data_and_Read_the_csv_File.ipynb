# %% [markdown]
# ## **2)— Upload the Data and Read the CSV File**
#
# ### **Objective**
#
# Load the salary dataset into a Python notebook and create a Pandas DataFrame for exploration.
#
# ---
#
# ### **Dataset Used**
#
# * `salaries_by_college_major.csv`
#   Contains salary statistics by undergraduate major, including starting salary, mid-career earnings, percentiles, and degree group.
#
# ---
#
# ### **Option A: Working in Google Colab**
#
# #### **Uploading the CSV File**
#
# 1. Download `salaries_by_college_major.csv` from the course resources.
# 2. Open the **Files** sidebar (folder icon) in Google Colab.
# 3. Drag and drop the CSV file into the sidebar.
#
# Once uploaded, the file becomes available in the current Colab session.
#
# ---
#
# #### **Reading the CSV File**
#
# ```python
# import pandas as pd
#
# df = pd.read_csv('salaries_by_college_major.csv')
# ```
#
# ---
#
# ### **Option B: Working in Jupyter Notebook (Local)**
#
# #### **Preparing the File**
#
# 1. Place `salaries_by_college_major.csv` in the same directory as the notebook file
#    or provide the correct relative or absolute path.
#
# ---
#
# #### **Reading the CSV File**
#
# ```python
# import pandas as pd
#
# df = pd.read_csv('salaries_by_college_major.csv')
# ```
#
# ---
#
# ### **Inspecting the Data**
#
# After loading the dataset, preview the DataFrame:
#
# ```python
# df.head()
# ```
#
# This displays the first five rows and allows verification of:
#
# * Column names
# * Data types
# * Dataset structure
#
# ---
#
# ### **Notebook Execution**
#
# * Execute a cell using **Shift + Enter**
# * Output is displayed directly below the cell
#
# ---
#
# ### **Productivity Tip**
#
# Enable code autocompletion to reduce typing:
#
# * **Windows:** `Ctrl + Space`
# * **Mac:** `Cmd + Space`
#
# ---
#
# ### **Learning Outcome**
#
# You have successfully:
#
# * Imported external data into a notebook environment
# * Loaded a CSV file using Pandas
# * Created a DataFrame ready for exploration
#
# ---
#
# ### **Up Next**
#
# **3)— Preliminary Data Exploration and Data Cleaning with Pandas**
